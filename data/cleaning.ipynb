# %% [markdown]
# # Combining data

# %%
import os
import pandas as pd

# %%
FILE = "bus_stops_combine.csv"

if os.path.isfile(f"./{FILE}") == True:
    os.remove(FILE)

# %% [markdown]
# ### Clean data and write to file

# %%
def generate_stop_id(s):
    # split string into char and
    # convert each char to its equivalent Ascii value
    asc_eqi = [ord(c) for c in s]

    # sum the Ascii values together, divide by 10 to cap result and return
    return round(sum(asc_eqi) / 10)

# %%
read_file = pd.read_excel("./bus_stops.xlsx", sheet_name=None, index_col=0)

for file, df in read_file.items():
    # clean, add, split data
    df = df[~df["GPS Location"].str.contains("no bus stop", case=False)]
    df = df.assign(bus_svc = file)
    df["GPS Location"] = df["GPS Location"].astype('string')
    df[["latitude", "longtitude"]] = df["GPS Location"].str.split(",", expand=True)
    df["stop_id"] = df["Bus stop"].apply(lambda s: generate_stop_id(s))

    # reformat
    df["stop_no"] = df.index
    df.set_index("stop_id", inplace=True)
    df.rename(columns={"Bus stop": "bus_stop"}, inplace=True)
    df = df[["stop_no", "bus_stop", "latitude", "longtitude", "bus_svc"]]

    # write to file
    df.to_csv(FILE, index=True, mode="a", header=not os.path.exists(FILE), encoding='utf-8')

# %% [markdown]
# ### Check written data

# %%
df = pd.read_csv("./bus_stops_combine.csv", dtype=object)

df.head(n=20)
# Out:
#    stop_id stop_no                                           bus_stop  \
# 0      147       1                                    Larkin Terminal
# 1      291       2                   Pejabat Daerah Tanah Johor Bahru
# 2      311       3                 RTM Jabatan Penyiaran Negeri Johor
# 3      190       4                              Opp Masjid Kolam Ayer
# 4      262       5                       Opp Jabatan Pendidikan Johor
# 5      364       6          Maktab Sultan Abu Bakar (English College)
# 6      232       7                           Hospital Sultanah Aminah
# 7      201       8                              Johor Islamic Complex
# 8      220       9                            Bangunan Sultan Ibrahim
# 9      172      10                                  Wisma Persekutuan
# 10     262      11                       Majlis Bandaraya Johor Bahru
# 11     176      12                                JB Sentral Terminal
# 12     184      13                               Menara MSC Cyberport
# 13     453      14  Opp Sekolah Kebangsaan Perempuan Jalan Yahya Awal
# 14     296      15                  Petronas Kiosk @ Jalan Yahya Awal
# 15     224      16                       Opp SJK (T) Jalan Yahya Awal
# 16     191      17                              aft Jalan Tasek Utara
# 17     307      18                  Opp Yayasan Bandaraya Johor Bahru
# 18     147      19                                    Larkin Terminal
# 19     166       1                                Hub PPR Sri Stulang
#
#               latitude           longtitude    bus_svc
# 0   1.4964559999542668   103.74374661113058  P101-loop
# 1    1.491850778809332   103.74087255093272  P101-loop
# 2   1.4801823177394162    103.7368168221016  P101-loop
# 3   1.4689940555974177    103.7368740086021  P101-loop
# 4   1.4675510557185905   103.73673088953657  P101-loop
# 5   1.4627466510403129   103.73965194475493  P101-loop
# 6   1.4575742843315376   103.74670675307506  P101-loop
# 7    1.456742090233385   103.74938268472616  P101-loop
# 8   1.4598336266506124   103.76216068221784  P101-loop
# 9   1.4609620562865593   103.75782511045665  P101-loop
# 10  1.4555985388016415   103.76176881099856  P101-loop
# 11  1.4635691591027955   103.76499694129318  P101-loop
# 12  1.4622515143439279   103.77198033612271  P101-loop
# 13  1.4728712972429236   103.74885185047674  P101-loop
# 14  1.4753718119884702    103.7479248341084  P101-loop
# 15   1.478736856876273   103.74753116069688  P101-loop
# 16  1.4810361535128787   103.74738498637815  P101-loop
# 17  1.4843491421227393   103.74925303801986  P101-loop
# 18  1.4964559999542668   103.74374661113058  P101-loop
# 19   1.495066778509724   103.78766489813552    P102-01
